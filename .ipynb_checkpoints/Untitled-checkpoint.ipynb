# %%
import pandas as pd
import qgrid

# %%
x = pd.read_csv('pydf_M')

# %%
x
# Out:
#    Facility\nDensity   y1   y2   y3   y4   y5   y6   y7   y8   y9  y10  y11  \
# 0                p=1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    X  NaN
# 1                p=2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2                p=3  NaN  NaN  NaN  NaN  NaN    X  NaN  NaN    X  NaN  NaN
# 3                p=4  NaN  NaN  NaN  NaN  NaN    X  NaN  NaN    X  NaN  NaN
# 4                p=5  NaN  NaN  NaN  NaN  NaN    X  NaN  NaN    X    X  NaN
# 5                p=6  NaN  NaN    X  NaN  NaN    X  NaN  NaN  NaN    X  NaN
# 6                p=7  NaN  NaN    X    X  NaN    X  NaN  NaN  NaN    X  NaN
# 7                p=8  NaN  NaN    X    X    X    X  NaN  NaN  NaN    X  NaN
# 8                p=9  NaN  NaN    X    X    X    X  NaN    X  NaN    X  NaN
# 9               p=10  NaN  NaN    X    X    X    X  NaN    X    X    X  NaN
# 10              p=11    X    X    X    X    X    X  NaN  NaN    X    X  NaN
# ...

# %%
qgrid.show_grid(x)
